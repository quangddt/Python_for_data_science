# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8499e12e-8d1d-4577-a560-5b06a9689fcf" name="files[]" multiple disabled />
#      <output id="result-8499e12e-8d1d-4577-a560-5b06a9689fcf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving f500.csv to f500.csv

# %%
f500 = pd.read_csv("f500.csv", )

# %%
f500
# Out:
#                                           company  rank  revenues  \
# 0                                         Walmart     1    485873
# 1                                      State Grid     2    315199
# 2                                   Sinopec Group     3    267518
# 3                        China National Petroleum     4    262573
# 4                                    Toyota Motor     5    254694
# 5                                      Volkswagen     6    240264
# 6                               Royal Dutch Shell     7    240033
# 7                              Berkshire Hathaway     8    223604
# 8                                           Apple     9    215639
# 9                                     Exxon Mobil    10    205004
# 10                                       McKesson    11    198533
# 11                                             BP    12    186606
# 12                             UnitedHealth Group    13    184840
# ...
